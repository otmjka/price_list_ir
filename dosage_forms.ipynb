# %%
row_docs = get_dosage_row_docs()

# %%
len(row_docs.keys())
# Out:
# 755

# %%
row_docs
# Out:
# {285: [0,
#   207,
#   500,
#   522,
#   557,
#   1074,
#   1183,
#   1282,
#   1652,
#   2073,
#   2161,
#   2205,
#   2227,
#   2312,
#   2391,
#   2991,
#   3188,
#   3203,
#   3319,
#   3322,
#   3493,
#   3529,
#   3624,
#   3677,
#   3706,
#   3723,
#   3949,
#   4517,
#   4665,
#   4956,
#   5133,
#   5779,
#   5932,
#   6052,
#   6116,
#   6375,
#   6561,
#   6802,
#   6819,
#   6923,
#   7053,
#   7899,
#   8213,
#   8403,
#   8579,
#   8681,
#   8874,
#   9131,
#   9256,
#   9301,
#   9525,
#   9917,
#   10079,
#   10198,
#   10204,
#   10405,
#   10588,
#   10756,
#   10980,
#   11034,
#   11067,
#   11071,
#   11246,
#   12343,
#   12377,
#   12534,
#   12609,
#   12624,
#   12813,
#   12888,
#   12939,
#   12989,
#   13204,
#   13602,
#   13624,
#   13774,
#   14511,
#   14620,
#   14656,
#   14897,
#   16194,
#   16327,
#   16996,
#   17149,
#   17403,
#   17434,
#   17558,
#   17884,
#   18041,
#   18126,
#   18256,
#   18984,
#   19115,
#   19185,
#   19491,
# ...

# %%
dosage_forms_idx = build_dosage_forms_idx()

# %%
dosage_forms_idx.keys()
# Out:
# dict_keys(['terms_docs', 'row_id', 'id_row'])

# %%
dosage_terms_docs = dosage_forms_idx['terms_docs']

# %%
dosage_terms_docs.keys()
# Out:
# dict_keys(['лиофилизат', 'спрея', 'порошок', 'для', 'приготовления', 'пасты', 'субстанция', 'раствора', 'внутрибрюшного', 'введения', 'таблетки', 'пролонгированного', 'действия', '', 'покрытые', 'кишечнорастворимой', 'оболочкой', 'гранулы', 'эндотрахеального', 'раствор', 'внутримышечного', 'с', 'консервантом', 'экстракт', 'местного', 'применения', 'жидкий', 'спрей', 'назальный', 'детей', 'сок', 'суспензия', 'слизистой', 'оболочки', 'полости', 'рта', 'и', 'подкожного', 'тиомерсалом', 'суспензии', 'внутрисуставного', 'суппозитории', 'ректальные', 'диспергируемые', 'сырье', 'растительное', 'промывания', 'культура', 'клеток', 'монослойная', 'геля', 'приёма', 'внутрь', 'внутривенного', 'бальзам', 'приема', 'наружного', 'инстилляций', 'крем', 'резинки', 'жевательные', 'свежая', 'мята', 'мазь', 'концентрат', 'внутриглазного', 'гель', 'концентрата', 'ректального', 'аэрозоль', 'дозированный', 'дисперсии', 'гемодиафильтрации', 'наружнего', 'орошения', 'желудка', 'шипучие', 'эмульсии', 'внутрик
# ...
